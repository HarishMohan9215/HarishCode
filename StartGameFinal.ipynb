# %%
import tkinter as tk
from PIL import Image, ImageTk

class RummikubGUI:
    def __init__(self, master):
        self.master = master
        self.master.title("Rummikub Game")

        self.canvas = tk.Canvas(master, width=800, height=600)
        self.canvas.pack()

        # Loading background image
        self.background_image = Image.open(r"C:\Users\nidhi\Documents\Python Project\images\background_image.jpg")
        self.background_photo = ImageTk.PhotoImage(self.background_image)

        # placing the background image on the canvas
        self.canvas.create_image(0, 0, anchor=tk.NW, image=self.background_photo)
        self.canvas.image = self.background_photo  # referencing the background image

        # adding labels to the game
        self.label = tk.Label(self.canvas, text="Welcome to Rummikub!", font=("Helvetica", 35))
        self.label.place(relx=0.5, rely=0.1, anchor=tk.CENTER)

        self.start_button = tk.Button(self.canvas, text="Start Game", font=("Helvetica", 25), command=self.prompt_players)
        self.start_button.place(relx=0.5, rely=0.5, anchor=tk.CENTER)

        self.exit_button = tk.Button(self.canvas, text="Exit", font=("Helvetica", 15), command=self.master.destroy)
        self.exit_button.place(relx=0.5, rely=0.6, anchor=tk.CENTER)

    def prompt_players(self):
        self.start_button.destroy()  #  to remove the start button

        # label to display number of players
        self.player_label = tk.Label(self.canvas, text="Select number of players:", font=("Helvetica", 20))
        self.player_label.place(relx=0.5, rely=0.4, anchor=tk.CENTER)

        # buttons for choosing number of players
        self.two_players_button = tk.Button(self.canvas, text="2 Players", font=("Helvetica", 20), command=lambda: self.start_game(2))
        self.two_players_button.place(relx=0.3, rely=0.5, anchor=tk.CENTER)

        self.three_players_button = tk.Button(self.canvas, text="3 Players", font=("Helvetica", 20), command=lambda: self.start_game(3))
        self.three_players_button.place(relx=0.5, rely=0.5, anchor=tk.CENTER)

        self.four_players_button = tk.Button(self.canvas, text="4 Players", font=("Helvetica", 20), command=lambda: self.start_game(4))
        self.four_players_button.place(relx=0.7, rely=0.5, anchor=tk.CENTER)

    def start_game(self, num_players):
        self.player_label.destroy()  # remove player label
        self.two_players_button.destroy()  # remove player buttons
        self.three_players_button.destroy()
        self.four_players_button.destroy()

        # Use the 'num_players' variable in your game logic
        print(f"Starting game with {num_players} players.")

        # You can continue with the game setup based on the number of players chosen.

if __name__ == "__main__":
    root = tk.Tk()
    app = RummikubGUI(root)
    root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

class RummikubGUI:
    def __init__(self, master):
        self.master = master
        self.master.title("Rummikub Game")

        self.canvas = tk.Canvas(master, width=800, height=600)
        self.canvas.pack()

        # Loading background image
        self.background_image = Image.open(r"C:\Users\nidhi\Documents\Python Project\images\background_image.jpg")
        self.background_photo = ImageTk.PhotoImage(self.background_image)

        # Placing the background image on the canvas
        self.canvas.create_image(0, 0, anchor=tk.NW, image=self.background_photo)
        self.canvas.image = self.background_photo  # Referencing the background image

        # Adding labels to the game
        self.label = tk.Label(self.canvas, text="Welcome to Rummikub!", font=("Helvetica", 35))
        self.label.place(relx=0.5, rely=0.1, anchor=tk.CENTER)

        self.start_button = tk.Button(self.canvas, text="Start Game", font=("Helvetica", 25), command=self.prompt_players)
        self.start_button.place(relx=0.5, rely=0.5, anchor=tk.CENTER)

        self.exit_button = tk.Button(self.canvas, text="Exit", font=("Helvetica", 15), command=self.master.destroy)
        self.exit_button.place(relx=0.5, rely=0.6, anchor=tk.CENTER)

        self.num_of_player = 0  # Initialize the variable to hold the number of players

    def prompt_players(self):
        self.start_button.destroy()  # Remove the start button

        # Label to display number of players
        self.player_label = tk.Label(self.canvas, text="Select number of players:", font=("Helvetica", 20))
        self.player_label.place(relx=0.5, rely=0.4, anchor=tk.CENTER)

        # Buttons for choosing number of players
        self.two_players_button = tk.Button(self.canvas, text="2 Players", font=("Helvetica", 20), command=lambda: self.assign_players(2))
        self.two_players_button.place(relx=0.3, rely=0.5, anchor=tk.CENTER)

        self.three_players_button = tk.Button(self.canvas, text="3 Players", font=("Helvetica", 20), command=lambda: self.assign_players(3))
        self.three_players_button.place(relx=0.5, rely=0.5, anchor=tk.CENTER)

        self.four_players_button = tk.Button(self.canvas, text="4 Players", font=("Helvetica", 20), command=lambda: self.assign_players(4))
        self.four_players_button.place(relx=0.7, rely=0.5, anchor=tk.CENTER)

    def assign_players(self, num_of_player):
        self.num_of_player = num_of_player
        print(f"Selected number of players: {self.num_of_player}")
        # Here, 'self.num_of_player' holds the selected number of players. You can use it in your game setup or logic.

        # Additional actions based on the selected number of players can be added here.

        # For example, if you want to start the game immediately after selecting the number of players:
        # self.start_game()

    def start_game(self):
        if self.num_of_player == 0:
            print("Please select the number of players first.")
            return

        print(f"Starting game with {self.num_of_player} players.")
        # Use the 'self.num_of_player' variable in your game logic
        # You can continue with the game setup based on the number of players chosen.

if __name__ == "__main__":
    root = tk.Tk()
    app = RummikubGUI(root)
    root.mainloop()
# Out:
# Selected number of players: 2
